# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# '/home/sude/Downloads'

# %%
os.chdir("/home/sude/Downloads/")

# %%
ac = pd.read_csv('PDBbind2015_refined-core.dat',index_col=False,sep=' ')
print(ac.shape)
ac.head()
# Out:
# (3248, 7)
#    affinity    score    gauss1      gauss2  repulsion  hydrophobic  hydrogen
# 0 -2.745424 -3.13245  48.02108   434.90009    1.00229     17.16027   1.04153
# 1 -2.745424 -4.57551  45.86394   906.54910    4.54990      0.00000   7.21115
# 2 -2.745424 -4.58830  49.45446   708.90695    4.56065     10.12192   5.42312
# 3 -2.745424 -3.13634  54.99922   768.05907    5.70052     31.01157   2.34365
# 4 -2.814060 -5.04353  53.45864  1053.90858    1.63114      0.00000   2.94989

# %%
ac
# Out:
#        affinity     score     gauss1      gauss2  repulsion  hydrophobic  \
# 0     -2.745424  -3.13245   48.02108   434.90009    1.00229     17.16027
# 1     -2.745424  -4.57551   45.86394   906.54910    4.54990      0.00000
# 2     -2.745424  -4.58830   49.45446   708.90695    4.56065     10.12192
# 3     -2.745424  -3.13634   54.99922   768.05907    5.70052     31.01157
# 4     -2.814060  -5.04353   53.45864  1053.90858    1.63114      0.00000
# 5     -2.910150  -6.74904  113.76903  1481.08181    8.93015      4.11732
# 6     -2.910150  -4.16492   42.29731   660.09223    3.00852      8.73834
# 7     -2.965058  -3.76214   60.02820   726.13705    5.97046      0.00000
# 8     -2.978785  -4.11913   54.80789   748.67528    3.38569     37.28263
# 9     -2.992513  -9.43253  112.66393  1645.48020    3.35142     11.52286
# 10    -3.006240  -5.35717   77.16599   974.24645    3.67899     26.59395
# 11    -3.006240  -5.86004   72.87585   860.10664    2.22941     29.84266
# ...

# %%
ac.columns
# Out:
# Index(['affinity', 'score', 'gauss1', 'gauss2', 'repulsion', 'hydrophobic',
#        'hydrogen'],
#       dtype='object')

# %%
ac.dtypes
# Out:
# affinity       float64
# score          float64
# gauss1         float64
# gauss2         float64
# repulsion      float64
# hydrophobic    float64
# hydrogen       float64
# dtype: object

# %%
ac.describe()   #gives statistical information of the Numeric data in the choosen dataset
# Out:
#           affinity        score       gauss1       gauss2    repulsion  \
# count  3248.000000  3248.000000  3248.000000  3248.000000  3248.000000
# mean     -8.811549    -7.146752    93.867510  1347.249859     4.739716
# std       2.729615     2.328613    35.816121   552.642367     2.606303
# min     -16.362729   -15.398830     7.497280   269.989350     0.121460
# 25%     -10.734609    -8.691327    65.707425   937.015818     2.813320
# 50%      -8.895175    -7.134780    89.746905  1267.259360     4.309330
# 75%      -6.753744    -5.436285   117.929120  1675.342045     6.219677
# max      -2.745424     2.620890   298.021650  4202.325050    21.601870
#
#        hydrophobic     hydrogen
# count  3248.000000  3248.000000
# mean     31.802597     5.145502
# std      28.006997     3.584242
# min       0.000000     0.000000
# 25%       7.389995     2.212245
# 50%      26.738340     4.636870
# 75%      49.272855     7.445367
# max     178.904130    22.804180

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ac['hydrogen'].hist(bins=10)

plt.show()

# %%
ac['hydrophobic'].hist(bins=10)

plt.show()

# %%
ac.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c3a58d9e8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1c3a434940>]], dtype=object)

# %%
#Count of missing values for data set
ac.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# affinity       0
# score          0
# gauss1         0
# gauss2         0
# repulsion      0
# hydrophobic    0
# hydrogen       0
# dtype: int64

# %%
affi = ac
hydrogen = affi['hydrogen']
hydrogen
# Out:
# 0        1.04153
# 1        7.21115
# 2        5.42312
# 3        2.34365
# 4        2.94989
# 5        9.50998
# 6        3.35823
# 7        6.60893
# 8        0.96132
# 9        3.57822
# 10       1.16111
# 11       0.00000
# 12       6.05705
# 13       6.00302
# 14       1.65913
# 15      10.17536
# 16       5.48827
# 17      10.02226
# 18       1.44255
# 19       4.51728
# 20       0.42024
# 21       3.77169
# 22       0.68522
# 23       0.56603
# 24       6.43796
# 25       1.61883
# 26       5.22628
# 27       7.74304
# 28       3.22470
# 29       3.60433
#           ...
# 3218     4.42801
# 3219     4.65266
# 3220     4.23829
# 3221     2.96009
# 3222     6.76028
# 3223     5.90627
# 3224     8.67026
# 3225     5.75752
# 3226     4.56234
# 3227     3.41531
# 3228     6.92820
# 3229     4.87800
# 3230     6.46514
# 3231     4.27376
# 3232    10.06975
# 3233     5.85459
# 3234     8.70459
# 3235     4.91306
# 3236     5.07829
# 3237     5.50025
# 3238     5.69383
# ...

# %%
aff = affi['affinity']
aff
# Out:
# 0       -2.745424
# 1       -2.745424
# 2       -2.745424
# 3       -2.745424
# 4       -2.814060
# 5       -2.910150
# 6       -2.910150
# 7       -2.965058
# 8       -2.978785
# 9       -2.992513
# 10      -3.006240
# 11      -3.006240
# 12      -3.033694
# 13      -3.033694
# 14      -3.047421
# 15      -3.047421
# 16      -3.047421
# 17      -3.047421
# 18      -3.061148
# 19      -3.061148
# 20      -3.061148
# 21      -3.102330
# 22      -3.102330
# 23      -3.116057
# 24      -3.129784
# 25      -3.143511
# 26      -3.157238
# 27      -3.157238
# 28      -3.157238
# 29      -3.157238
#           ...
# 3218   -15.401831
# 3219   -15.415558
# 3220   -15.456739
# 3221   -15.484193
# 3222   -15.511648
# 3223   -15.511648
# 3224   -15.511648
# 3225   -15.511648
# 3226   -15.511648
# 3227   -15.511648
# 3228   -15.539102
# 3229   -15.580283
# 3230   -15.648919
# 3231   -15.648919
# 3232   -15.676373
# 3233   -15.813644
# 3234   -15.813644
# 3235   -15.841099
# 3236   -15.882280
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()

aff =labelencoder_x.fit_transform(aff)

# %%
affi['affinity']=aff

# %%
affi
# Out:
#       affinity     score     gauss1      gauss2  repulsion  hydrophobic  \
# 0          741  -3.13245   48.02108   434.90009    1.00229     17.16027
# 1          741  -4.57551   45.86394   906.54910    4.54990      0.00000
# 2          741  -4.58830   49.45446   708.90695    4.56065     10.12192
# 3          741  -3.13634   54.99922   768.05907    5.70052     31.01157
# 4          740  -5.04353   53.45864  1053.90858    1.63114      0.00000
# 5          739  -6.74904  113.76903  1481.08181    8.93015      4.11732
# 6          739  -4.16492   42.29731   660.09223    3.00852      8.73834
# 7          738  -3.76214   60.02820   726.13705    5.97046      0.00000
# 8          737  -4.11913   54.80789   748.67528    3.38569     37.28263
# 9          736  -9.43253  112.66393  1645.48020    3.35142     11.52286
# 10         735  -5.35717   77.16599   974.24645    3.67899     26.59395
# 11         735  -5.86004   72.87585   860.10664    2.22941     29.84266
# ...

# %%
ac.describe()
# Out:
#           affinity        score       gauss1       gauss2    repulsion  \
# count  3248.000000  3248.000000  3248.000000  3248.000000  3248.000000
# mean    362.517241    -7.146752    93.867510  1347.249859     4.739716
# std     177.083230     2.328613    35.816121   552.642367     2.606303
# min       0.000000   -15.398830     7.497280   269.989350     0.121460
# 25%     225.000000    -8.691327    65.707425   937.015818     2.813320
# 50%     351.000000    -7.134780    89.746905  1267.259360     4.309330
# 75%     500.000000    -5.436285   117.929120  1675.342045     6.219677
# max     741.000000     2.620890   298.021650  4202.325050    21.601870
#
#        hydrophobic     hydrogen
# count  3248.000000  3248.000000
# mean     31.802597     5.145502
# std      28.006997     3.584242
# min       0.000000     0.000000
# 25%       7.389995     2.212245
# 50%      26.738340     4.636870
# 75%      49.272855     7.445367
# max     178.904130    22.804180

# %%
ac.cov()
# Out:
#                  affinity       score        gauss1         gauss2  \
# affinity     31358.470291  194.507122  -2618.533914  -46780.078632
# score          194.507122    5.422437    -58.482498    -926.220409
# gauss1       -2618.533914  -58.482498   1282.794553   17119.369678
# gauss2      -46780.078632 -926.220409  17119.369678  305413.585344
# repulsion      -40.256900   -0.150275     48.687490     572.482865
# hydrophobic  -2228.656454  -37.413179    429.421387    8903.961087
# hydrogen        10.476731   -1.159621     51.452552     525.237475
#
#               repulsion  hydrophobic    hydrogen
# affinity     -40.256900 -2228.656454   10.476731
# score         -0.150275   -37.413179   -1.159621
# gauss1        48.687490   429.421387   51.452552
# gauss2       572.482865  8903.961087  525.237475
# repulsion      6.792813    -7.546858    7.042790
# hydrophobic   -7.546858   784.391903  -28.270397
# hydrogen       7.042790   -28.270397   12.846788

# %%
columns=['score','gauss1','gauss2','repulsion','hydrophobic','hydrogen']

x=ac[columns].values
y=ac.iloc[:,0].values


print(X.shape,y.shape)
# Out:
# (3248, 6) (3248,)

# %%
from sklearn.model_selection import train_test_split
# splitting the data to train and test

x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
m_train=x_train.shape[0]
m_val=x_val.shape[0]
# number of features
n=x_train.shape[1]
# Out:
# (2598, 6) (2598,)
# (650, 6) (650,)

# %% [markdown]
# ## SVM

# %%
# normalizing the data
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
sc_x=StandardScaler()
sc_x.fit(x_train)
x_train_std=sc_x.transform(x_train)
x_val_std=sc_x.transform(x_val)
sv=SVR(C=1)
sv.fit(x_train_std,y_train)
print(sv.score(x_train_std,y_train))
print(sv.score(x_val_std,y_val))
# Out:
# 0.279993049934
# 0.234324429203

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression,Ridge
lr=LinearRegression()
lr.fit(x_train,y_train)
print(lr.score(x_train,y_train))
print(lr.score(x_val,y_val))
# Out:
# 0.311539958219
# 0.256015221186

# %% [markdown]
# ## RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 35,max_depth=7, random_state = 42)
rf.fit(x_train, y_train);
print(rf.score(x_train,y_train))
print(rf.score(x_val,y_val))
# Out:
# 0.59132365742
# 0.406811058838

# %% [markdown]
#  ## MODEL SELECTION
#
# So the given data has been splitted into train and validation.So I took the Size of the Valdation to be 0.2 times the size of train data. I have chosen 4 models namely , linear regression,SVR and random forest regressor.
# The hyperparameters for the models were chosen by seeing the validation score. The model was selected based only on validation score. (1====>good prediction and 0 =====>bad prediction).
# So from the models above  I select the random forest for prediciton on the test data.

# %%
test=pd.read_csv("PDBbind2015_core.dat",sep=' ',index_col=False)
print(test.shape)
test.head()

# %%
x_test=abc[columns].values
y_test=abc.iloc[:,0].values

print(x_test.shape,y_test.shape)

# %%
y_predict=rf.predict(x_test)

print("Testing score is",rf.score(x_test))
